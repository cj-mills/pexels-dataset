# %% [markdown]
# **Install dependencies**

# %%
# !pip install -U pandas pillow
# !pip install -U cjm_pil_utils

# %% [markdown]
# **Import dependencies**

# %%
# Import the random, pathlib, and PIL modules
import random
from pathlib import Path
from PIL import Image

import pandas as pd
pd.set_option('max_colwidth', None)  # Do not truncate the contents of cells in the DataFrame
pd.set_option('display.max_rows', None)  # Display all rows in the DataFrame
pd.set_option('display.max_columns', None)  # Display all columns in the DataFrame

# %%
from cjm_pil_utils.core import get_img_files

# %% [markdown]
# **Define path to image attribute data**

# %%
# Set the file path for the attributes dataframe
attributes_df_json_file = '../attributes_df.json'

# Print the file path
print(attributes_df_json_file)
# Out:
# ../attributes_df.json

# %% [markdown]
# **Import image attributes**

# %%
# Read the attributes dataframe from the JSON file
attributes_df = pd.read_json(attributes_df_json_file)

# Print the number of entries in the dataframe
print(f"Number of entries: {len(attributes_df)}")

# Display the first few rows of the dataframe
attributes_df.head().transpose()
# Out:
# Number of entries: 109971
#                                                                                                                                                                                                                                                                                                                                                                       3186010  \
# title                                                                                                                                                                                                                                                                                                                                   Pink and White Ice Cream Neon Signage
# aspect_ratio                                                                                                                                                                                                                                                                                                                                                         0.749809
# main_color                                                                                                                                                                                                                                                                                                                                                      [128, 38, 77]
# colors                                                                                                                                                                                                                                                                                                                 [#000000, #a52a2a, #bc8f8f, #c71585, #d02090, #d8bfd8]
# tags             [bright, chocolate, close-up, cold, cream, creamy, cup, dairy product, delicious, design, dessert, electricity, epicure, flavors, fluorescent, food, food photography, goody, hand, ice cream, icecream, illuminated, indulgence, light pink background, neon, neon lights, neon sign, pastry, pink background, pink wallpaper, scoop, sweet, sweets, tasty]
# adult                                                                                                                                                                                                                                                                                                                                                           very_unlikely
# aperture                                                                                                                                                                                                                                                                                                                                                                  1.8
# camera                                                                                                                                                                                                                                                                                                                                                               iPhone X
# focal_length                                                                                                                                                                                                                                                                                                                                                              4.0
# google_place_id                                                                                                                                                                                                                                                                                                                                   ChIJkUjxJ7it1y0R4qOVTbWHlR4
# iso                                                                                                                                                                                                                                                                                                                                                                      40.0
# latitude                                                                                                                                                                                                                                                                                                                                                            -7.746914
# longitude                                                                                                                                                                                                                                                                                                                                                          113.226906
# manufacturer                                                                                                                                                                                                                                                                                                                                                            Apple
# medical                                                                                                                                                                                                                                                                                                                                                         very_unlikely
# orientation                                                                                                                                                                                                                                                                                                                                                               0.0
# racy                                                                                                                                                                                                                                                                                                                                                                 unlikely
# shutter_speed
# software                                                                                                                                                                                                                                                                                                                                                               13.1.3
# spoof                                                                                                                                                                                                                                                                                                                                                           very_unlikely
# violence                                                                                                                                                                                                                                                                                                                                                        very_unlikely
# location                                                                                                                                                                                                                                                                                                                            Kecamatan Mayangan, Jawa Timur, Indonesia
#
#                                                                                                                                                          3185509  \
# title                                                                                                                       Garnishing of Syrup on a Cheesecake
# aspect_ratio                                                                                                                                                 1.0
# main_color                                                                                                                                       [185, 167, 164]
# colors                                                                                                             [#000000, #696969, #bc8f8f, #cd5c5c, #d3d3d3]
# tags             [cheesecake, dessert, epicure, food photography, food plating, food porn, food preparation, food styling, garnishing, gastronomy, glaze, syrup]
# adult                                                                                                                                              very_unlikely
# aperture                                                                                                                                                     NaN
# camera
# focal_length                                                                                                                                                 NaN
# google_place_id                                                                                                                                             None
# iso                                                                                                                                                          NaN
# latitude                                                                                                                                                     NaN
# longitude                                                                                                                                                    NaN
# manufacturer
# medical                                                                                                                                            very_unlikely
# orientation                                                                                                                                                  NaN
# racy                                                                                                                                                    unlikely
# shutter_speed
# software
# spoof                                                                                                                                              very_unlikely
# violence                                                                                                                                           very_unlikely
# location                                                                                                                                                    None
#
#                                                                                                                                                                                                                                                   3182800  \
# title                                                                                                                                                                                                                    People in Front of the Computers
# aspect_ratio                                                                                                                                                                                                                                     1.498501
# main_color                                                                                                                                                                                                                                [176, 175, 169]
# colors                                                                                                                                                                                                      [#000000, #696969, #a9a9a9, #add8e6, #f5f5f5]
# tags             [colleagues, computer, connection, cooperation, desk, dreadlocks, employees, facial expression, furniture, indoors, internet, looking, office, people, room, sit, sitting, table, teamwork, technology, women, work, working, workplace]
# adult                                                                                                                                                                                                                                            unlikely
# aperture                                                                                                                                                                                                                                              NaN
# camera                                                                                                                                                                                                                                               None
# focal_length                                                                                                                                                                                                                                          NaN
# google_place_id                                                                                                                                                                                                                                      None
# iso                                                                                                                                                                                                                                                   NaN
# latitude                                                                                                                                                                                                                                              NaN
# longitude                                                                                                                                                                                                                                             NaN
# manufacturer                                                                                                                                                                                                                                         None
# medical                                                                                                                                                                                                                                     very_unlikely
# orientation                                                                                                                                                                                                                                           1.0
# racy                                                                                                                                                                                                                                             possible
# shutter_speed                                                                                                                                                                                                                                        None
# software                                                                                                                                                                                                              Adobe Photoshop CC 2015 (Macintosh)
# spoof                                                                                                                                                                                                                                       very_unlikely
# violence                                                                                                                                                                                                                                    very_unlikely
# location                                                                                                                                                                                                                                             None
#
#                                                                                                                                                                                                                   3184308  \
# title                                                                                                                                                                                  Photo Of People Next To Each Other
# aspect_ratio                                                                                                                                                                                                          1.5
# main_color                                                                                                                                                                                                [201, 179, 150]
# colors                                                                                                                                                                      [#708090, #a0522d, #cd853f, #eedd82, #ffdab9]
# tags             [adults, casual, communication, conversation, fashion, fashionable, fun, gather, gathered, gathering, happiness, happy, leisure, outfit, recreation, sit, sitting, smile, smiling, style, stylish, wear]
# adult                                                                                                                                                                                                            unlikely
# aperture                                                                                                                                                                                                              NaN
# camera                                                                                                                                                                                                               None
# focal_length                                                                                                                                                                                                          NaN
# google_place_id                                                                                                                                                                                                      None
# iso                                                                                                                                                                                                                   NaN
# latitude                                                                                                                                                                                                              NaN
# longitude                                                                                                                                                                                                             NaN
# manufacturer                                                                                                                                                                                                         None
# medical                                                                                                                                                                                                     very_unlikely
# orientation                                                                                                                                                                                                           1.0
# racy                                                                                                                                                                                                             possible
# shutter_speed                                                                                                                                                                                                        None
# software                                                                                                                                                                              Adobe Photoshop CC 2015 (Macintosh)
# spoof                                                                                                                                                                                                       very_unlikely
# violence                                                                                                                                                                                                    very_unlikely
# location                                                                                                                                                                                                             None
#
#                                                                                                                                           3185747
# title                                                                                                  Aerial View of Coconut Trees at Rural Area
# aspect_ratio                                                                                                                             1.499795
# main_color                                                                                                                        [154, 139, 128]
# colors                                                                                                                         [#696969, #808080]
# tags             [aerial shot, coconut trees, daylight, drone shot, exotic, high angle shot, outdoors, palm trees, sand, summer, trees, tropical]
# adult                                                                                                                                        None
# aperture                                                                                                                                      2.6
# camera                                                                                                                                     FC1102
# focal_length                                                                                                                                 4.49
# google_place_id                                                                                                                              None
# iso                                                                                                                                         100.0
# latitude                                                                                                                                      NaN
# longitude                                                                                                                                     NaN
# manufacturer                                                                                                                                  DJI
# medical                                                                                                                                      None
# orientation                                                                                                                                   0.0
# racy                                                                                                                                         None
# shutter_speed                                                                                                                                None
# software                                                                                                  Adobe Photoshop Lightroom 5.7 (Windows)
# spoof                                                                                                                                        None
# violence                                                                                                                                     None
# location                                                                                                                                     None

# %% [markdown]
# **Get only image titles**

# %%
# Create a dataframe of the 'title' column from the attributes dataframe
title_df = attributes_df['title'].to_frame()

# Display the first few rows of the dataframe
title_df.head()
# Out:
#                                               title
# 3186010       Pink and White Ice Cream Neon Signage
# 3185509        Garnishing of Syrup on a Cheesecake
# 3182800            People in Front of the Computers
# 3184308          Photo Of People Next To Each Other
# 3185747  Aerial View of Coconut Trees at Rural Area

# %% [markdown]
# **Get image ids**

# %%
# Create a list of the indexes of the attributes dataframe
img_ids = attributes_df.index.to_list()

# Print the first index from the list
print(img_ids[0])
# Out:
# 3186010

# %% [markdown]
# **Define path to image dataset**

# %%
# Set the path for the data directory
data_dir = Path("/mnt/980_1TB_2/Datasets/")

# Set the path for the images directory
img_dir = Path(data_dir/"pexels-110k-512p-min-jpg/images/")

# %% [markdown]
# **Get image file paths**

# %%
# Get a list of the paths to the images in the images directory
img_paths = get_img_files(img_dir)

# Print the number of images in the images directory
print(len(img_paths))
# Out:
# 109971

# %% [markdown]
# **Create image path dictionary**

# %%
# Create a dictionary mapping image IDs to image paths
img_path_dict = {int(path.stem.split('-')[-1]) : path for path in img_paths}

# Display the first few entries in the dictionary using a Pandas Dataframe
pd.DataFrame.from_dict(img_path_dict, orient='index').head()
# Out:
#                                                                                                                    0
# 1061142                         /mnt/980_1TB_2/Datasets/pexels-110k-512p-min-jpg/images/1-art-background-1061142.jpg
# 2586334  /mnt/980_1TB_2/Datasets/pexels-110k-512p-min-jpg/images/1-person-beauty-face-blurred-background-2586334.jpg
# 1460032                     /mnt/980_1TB_2/Datasets/pexels-110k-512p-min-jpg/images/1-wtc-artist-concert-1460032.jpg
# 1061133                          /mnt/980_1TB_2/Datasets/pexels-110k-512p-min-jpg/images/10-art-artistic-1061133.jpg
# 1339845                             /mnt/980_1TB_2/Datasets/pexels-110k-512p-min-jpg/images/10-art-color-1339845.jpg

# %% [markdown]
# **Display sample image**

# %%
# Choose a random image ID from the list of image IDs
img_id = random.choice(img_ids)

print(f"ID: {img_id}")

# Open the image located at the path in the img_path_dict with the key of the current img_id
sample_img = Image.open(img_path_dict[img_id])

# Print the title of the image, located in the 'title' column of the attributes_df dataframe
print(f"Title: {attributes_df.loc[img_id]['title']}")

# Print the title of the image, located in the 'title' column of the attributes_df dataframe
print(f"Tags: {', '.join(attributes_df.loc[img_id]['tags'])}")

# Display the image
sample_img
# Out:
# ID: 3105062
# Title: Light Streaks
# Tags: light, light streaks, long exposure, road, road at night
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=768x512>

# %% [markdown]
# **Inspect tags for selected image**

# %%
# Retrieve the list of tags for the current image (identified by img_id)
# from the 'tags' column in the attributes_df dataframe
attributes_df.loc[img_id]['tags']
# Out:
# ['light', 'light streaks', 'long exposure', 'road', 'road at night']

# %% [markdown]
# **Search dataset for a specific tag**

# %%
# Define the search term
tag_term = 'golden hour'

# Create a mask for the attributes_df dataframe to identify rows where the 'tags' column contains the search term
mask = attributes_df.tags.apply(lambda x: tag_term in x if x is not None else False)

# Create a new dataframe containing only the rows that match the mask
results_df = attributes_df[mask]

# Print the number of rows in the resulting dataframe
print(f"Found {len(results_df)} entries")

# Display the first few rows of the resulting dataframe
results_df.head().transpose()
# Out:
# Found 1293 entries
#                                                                                                                                                                                                                   3157917  \
# title                                                                                                                                                                                         Photo Of Sunset During Dawn
# aspect_ratio                                                                                                                                                                                                     1.333234
# main_color                                                                                                                                                                                                 [152, 118, 96]
# colors                                                                                                                                                                                        [#000000, #deb887, #e9967a]
# tags             [afterglow, calm, dawn, dusk, environment, golden hour, horizon, idyllic, nature, nature photography, ocean, peaceful, ripples, scenery, scenic, sea, seascape, sun, sunbeam, sunrise, sunset, tranquil]
# adult                                                                                                                                                                                                       very_unlikely
# aperture                                                                                                                                                                                                              1.7
# camera                                                                                                                                                                                                      ONEPLUS A6013
# focal_length                                                                                                                                                                                                         4.25
# google_place_id                                                                                                                                                                               ChIJCxgesixFDhMR0oAyeQNvqig
# iso                                                                                                                                                                                                                 100.0
# latitude                                                                                                                                                                                                        35.895207
# longitude                                                                                                                                                                                                         14.5125
# manufacturer                                                                                                                                                                                                      OnePlus
# medical                                                                                                                                                                                                     very_unlikely
# orientation                                                                                                                                                                                                           1.0
# racy                                                                                                                                                                                                        very_unlikely
# shutter_speed                                                                                                                                                                                                        None
# software                                                                                                                                                                                                     Snapseed 2.0
# spoof                                                                                                                                                                                                       very_unlikely
# violence                                                                                                                                                                                                    very_unlikely
# location                                                                                                                                                                                          Il-Belt Valletta, Malta
#
#                                                                                                                                      3150702  \
# title                                                                                Aerial Photography of City Buildings During Golden Hour
# aspect_ratio                                                                                                                        0.669421
# main_color                                                                                                                    [137, 102, 94]
# colors                                                                                                  [#000000, #696969, #ff7f50, #ffa07a]
# tags             [city, dawn, dusk, fog, foggy, golden hour, hills, morning, scenery, scenic, silhouette, sky, sunrise, sunset, urban, view]
# adult                                                                                                                          very_unlikely
# aperture                                                                                                                                 5.6
# camera                                                                                                                           NIKON D3000
# focal_length                                                                                                                            70.0
# google_place_id                                                                                                                         None
# iso                                                                                                                                    100.0
# latitude                                                                                                                                 NaN
# longitude                                                                                                                                NaN
# manufacturer                                                                                                               NIKON CORPORATION
# medical                                                                                                                        very_unlikely
# orientation                                                                                                                              1.0
# racy                                                                                                                           very_unlikely
# shutter_speed                                                                                                                           None
# software                                                                                                 Adobe Photoshop CC 2019 (Macintosh)
# spoof                                                                                                                          very_unlikely
# violence                                                                                                                       very_unlikely
# location                                                                                                                                None
#
#                                                                                                                                                          3157967  \
# title                                                                                                                                Calm Sea During Golden Hour
# aspect_ratio                                                                                                                                                 1.5
# main_color                                                                                                                                        [119, 107, 97]
# colors                                                                                                                                        [#000000, #faebd7]
# tags             [clouds, dawn, dusk, golden hour, horizon, islands, ocean, outdoors, rock formation, sea, seashore, shore, sky, sunrise, sunset, travel, water]
# adult                                                                                                                                              very_unlikely
# aperture                                                                                                                                                     7.1
# camera                                                                                                                                              Canon EOS 6D
# focal_length                                                                                                                                                30.0
# google_place_id                                                                                                                                             None
# iso                                                                                                                                                        100.0
# latitude                                                                                                                                                     NaN
# longitude                                                                                                                                                    NaN
# manufacturer                                                                                                                                               Canon
# medical                                                                                                                                            very_unlikely
# orientation                                                                                                                                                  0.0
# racy                                                                                                                                               very_unlikely
# shutter_speed                                                                                                                                               None
# software                                                                                                         Adobe Photoshop Lightroom Classic 8.1 (Windows)
# spoof                                                                                                                                              very_unlikely
# violence                                                                                                                                           very_unlikely
# location                                                                                                                                                    None
#
#                                                                                                           3170887  \
# title                                                                           Photo of Trees During Golden Hour
# aspect_ratio                                                                                             0.666667
# main_color                                                                                        [142, 140, 132]
# colors                                                                                         [#000000, #dcdcdc]
# tags             [dawn, dusk, environment, forest, golden hour, horizon, nature, outdoors, scenery, trees, woods]
# adult                                                                                                        None
# aperture                                                                                                      1.8
# camera                                                                                          Canon EOS Kiss X7
# focal_length                                                                                                 50.0
# google_place_id                                                                                              None
# iso                                                                                                         100.0
# latitude                                                                                                      NaN
# longitude                                                                                                     NaN
# manufacturer                                                                                                Canon
# medical                                                                                                      None
# orientation                                                                                                   0.0
# racy                                                                                                         None
# shutter_speed                                                                                                None
# software                                                          Adobe Photoshop Lightroom Classic 8.4 (Windows)
# spoof                                                                                                        None
# violence                                                                                                     None
# location                                                                                                     None
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  3163677
# title                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Photo Of People In Front Of Mosque During Golden Hour
# aspect_ratio                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    1.509804
# main_color                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                [189, 145, 91]
# colors                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       [#8b4513, #deb887, #faebd7]
# tags             [arches, architectural building, architectural design, architectural detail, architecture, belief, blue mosque, building, celebration, crowd, crowded, culture, dawn, daylight, delhi, domes, dusk, eid, exterior, faith, gathering, golden hour, grand mosque, historic, historical building, house of worship, islam, islamic architecture, jama, landmark, masjid, minarets, monument, mosque, muslim, muslims, outdoors, people, pillars, prayers, praying, ramadan, religion, religious, sacred, salah, sheikh zayed mosque, spirituality, square, sultan ahmed mosque, sun, sunbeam, sunlight, sunrays, sunrise, sunset, sunshine, temple, towers, tradition, traditional, travel, trust, turning point, worship]
# adult                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      very_unlikely
# aperture                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            11.0
# camera                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       NIKON D7000
# focal_length                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        18.0
# google_place_id                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     None
# iso                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                100.0
# latitude                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             NaN
# longitude                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            NaN
# manufacturer                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           NIKON CORPORATION
# medical                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    very_unlikely
# orientation                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          0.0
# racy                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       very_unlikely
# shutter_speed
# software                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Adobe Photoshop Express 9.0 (Android)
# spoof                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      very_unlikely
# violence                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   very_unlikely
# location                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            None

# %% [markdown]
# **Get image IDs from search results**

# %%
# Retrieve a list of the image IDs for the entries in the results_df dataframe
results_df_img_ids = results_df.index.to_list()

# Print the first image ID in the list
print(results_df_img_ids[0])
# Out:
# 3157917

# %% [markdown]
# **Select an image ID**

# %%
# Choose a random image ID from the list of image IDs in the results_df dataframe
results_img_id = random.choice(results_df_img_ids)

# Print the chosen image ID
print(results_img_id)
# Out:
# 1539759

# %% [markdown]
# **Inspect an image from the search results**

# %%
# Open the image located at the path in the img_path_dict with the key of the current results_img_id
sample_img = Image.open(img_path_dict[results_img_id])

# Print the title of the image, located in the 'title' column of the attributes_df dataframe
print(f"Title: {attributes_df.loc[results_img_id]['title']}")

# Display the image
sample_img
# Out:
# Title: Silhouette Photography of Woman at Golden Hour
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=768x512>
